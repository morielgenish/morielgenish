# %% [markdown]
# <a href="https://colab.research.google.com/github/morielgenish/morielgenish/blob/main/WeatherDataSet_MorielGenish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc6e8bcb-b49b-4a93-bc02-40f8b5dcdcfd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc6e8bcb-b49b-4a93-bc02-40f8b5dcdcfd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("weatherHistory.csv")

# %% [markdown]
# Explore our Data

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data.tail(10)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96443  2016-09-09 14:00:00.000 +0200  Partly Cloudy        rain
# 96444  2016-09-09 15:00:00.000 +0200  Partly Cloudy        rain
# 96445  2016-09-09 16:00:00.000 +0200  Partly Cloudy        rain
# 96446  2016-09-09 17:00:00.000 +0200  Partly Cloudy        rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy        rain
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96443        30.894444                 29.450000      0.28            14.7798
# 96444        31.083333                 29.616667      0.28            15.5043
# ...

# %%
data.shape
# Out:
# (96453, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data.dtypes # data types of each column
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
data.Humidity.unique()
# Out:
# array([0.89, 0.86, 0.83, 0.85, 0.95, 0.82, 0.72, 0.67, 0.54, 0.55, 0.51,
#        0.47, 0.46, 0.6 , 0.63, 0.69, 0.7 , 0.77, 0.76, 0.79, 0.62, 0.66,
#        0.8 , 0.78, 0.61, 0.52, 0.4 , 0.37, 0.36, 0.43, 0.5 , 0.53, 0.58,
#        0.59, 0.87, 0.93, 0.84, 0.73, 0.71, 0.74, 0.81, 0.9 , 0.99, 0.96,
#        0.75, 0.88, 0.65, 0.91, 0.94, 0.92, 0.44, 0.56, 0.68, 0.64, 0.48,
#        0.57, 0.98, 1.  , 0.38, 0.41, 0.45, 0.49, 0.32, 0.42, 0.35, 0.39,
#        0.97, 0.34, 0.33, 0.31, 0.3 , 0.29, 0.27, 0.28, 0.26, 0.24, 0.25,
#        0.23, 0.19, 0.17, 0.2 , 0.15, 0.18, 0.22, 0.14, 0.21, 0.16, 0.13,
#        0.  , 0.12])

# %%
data['Temperature (C)'].unique()
# Out:
# array([ 9.47222222,  9.35555556,  9.37777778, ..., 28.47222222,
#        28.33888889, 30.60555556])

# %%
data['Temperature (C)'].nunique()
# Out:
# 7574

# %%
data.count() # number of non-null values in each column
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
data.Humidity.value_counts()
# Out:
# Humidity
# 0.93    5708
# 0.92    3888
# 0.96    3843
# 1.00    2890
# 0.89    2837
#         ...
# 0.15      10
# 0.16       8
# 0.14       4
# 0.13       1
# 0.12       1
# Name: count, Length: 90, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# 1. Find all the unique "Wind Speed" values in the data

# %%
data['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [markdown]
# 2. Find the number of times when the "Rain until afternoon."

# %%
data['Daily Summary'].value_counts()
# Out:
# Daily Summary
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
data[data['Daily Summary'] == 'Rain until afternoon.']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 95420  2016-10-26 00:00:00.000 +0200     Light Rain        rain
# 95421  2016-10-26 01:00:00.000 +0200     Light Rain        rain
# 95422  2016-10-26 02:00:00.000 +0200     Light Rain        rain
# 95423  2016-10-26 03:00:00.000 +0200     Light Rain        rain
# 95424  2016-10-26 04:00:00.000 +0200           Rain        rain
# 95425  2016-10-26 05:00:00.000 +0200           Rain        rain
# 95426  2016-10-26 06:00:00.000 +0200           Rain        rain
# 95427  2016-10-26 07:00:00.000 +0200           Rain        rain
# 95428  2016-10-26 08:00:00.000 +0200           Rain        rain
# 95429  2016-10-26 09:00:00.000 +0200           Rain        rain
# 95430  2016-10-26 10:00:00.000 +0200     Light Rain        rain
# 95431  2016-10-26 11:00:00.000 +0200     Light Rain        rain
# 95432  2016-10-26 12:00:00.000 +0200     Light Rain        rain
# 95433  2016-10-26 13:00:00.000 +0200        Drizzle        rain
# ...

# %%
data.groupby('Daily Summary').get_group('Rain until afternoon.')
# Out:
#                       Formatted Date        Summary Precip Type  \
# 95420  2016-10-26 00:00:00.000 +0200     Light Rain        rain
# 95421  2016-10-26 01:00:00.000 +0200     Light Rain        rain
# 95422  2016-10-26 02:00:00.000 +0200     Light Rain        rain
# 95423  2016-10-26 03:00:00.000 +0200     Light Rain        rain
# 95424  2016-10-26 04:00:00.000 +0200           Rain        rain
# 95425  2016-10-26 05:00:00.000 +0200           Rain        rain
# 95426  2016-10-26 06:00:00.000 +0200           Rain        rain
# 95427  2016-10-26 07:00:00.000 +0200           Rain        rain
# 95428  2016-10-26 08:00:00.000 +0200           Rain        rain
# 95429  2016-10-26 09:00:00.000 +0200           Rain        rain
# 95430  2016-10-26 10:00:00.000 +0200     Light Rain        rain
# 95431  2016-10-26 11:00:00.000 +0200     Light Rain        rain
# 95432  2016-10-26 12:00:00.000 +0200     Light Rain        rain
# 95433  2016-10-26 13:00:00.000 +0200        Drizzle        rain
# ...

# %% [markdown]
# 3. Find the number of times Wind Speed was exactly 4.2021 km/h

# %%
data['Wind Speed (km/h)'].value_counts()
# Out:
# Wind Speed (km/h)
# 3.2200     2441
# 11.2700    1495
# 6.4400     1357
# 0.0000     1297
# 8.0500      920
#            ...
# 34.3413       1
# 45.9333       1
# 31.5238       1
# 32.5864       1
# 41.6990       1
# Name: count, Length: 2484, dtype: int64

# %%
data[data['Wind Speed (km/h)'] == 4.2021]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 348    2006-04-22 12:00:00.000 +0200  Partly Cloudy        rain
# 590    2006-04-04 14:00:00.000 +0200       Overcast        rain
# 3007   2006-01-14 07:00:00.000 +0100          Foggy        snow
# 3929   2006-07-20 17:00:00.000 +0200  Partly Cloudy        rain
# 4350   2006-07-09 06:00:00.000 +0200  Partly Cloudy        rain
# 4742   2006-06-23 14:00:00.000 +0200  Mostly Cloudy        rain
# 4787   2006-06-25 11:00:00.000 +0200  Partly Cloudy        rain
# 6537   2006-05-08 10:00:00.000 +0200  Mostly Cloudy        rain
# 9317   2007-04-03 05:00:00.000 +0200  Partly Cloudy        rain
# 12565  2007-07-15 13:00:00.000 +0200  Partly Cloudy        rain
# 13793  2007-06-06 17:00:00.000 +0200  Partly Cloudy        rain
# 21052  2008-01-04 04:00:00.000 +0100  Mostly Cloudy        snow
# 29800  2009-01-31 16:00:00.000 +0100  Mostly Cloudy        rain
# 36883  2010-12-21 19:00:00.000 +0100  Partly Cloudy        rain
# ...

# %% [markdown]
# 4. Find all the null values in the data

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %% [markdown]
# 5.Rename the column 'Daily Summary' to 'Weather Condition'

# %%
data.rename(columns = {'Daily Summary': 'Weather Condition'}, inplace = True)

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                    Weather Condition
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %% [markdown]
# 6. What is the mean of 'Visibility'?

# %%
data['Visibility (km)'].mean()
# Out:
# 10.347324929240148

# %% [markdown]
# 7.What is the std of 'Pressure' in this data?

# %%
data['Pressure (millibars)'].std()
# Out:
# 116.96990568258147

# %% [markdown]
# 8. what is the Variance of Humidity?

# %%
data['Humidity'].var()
# Out:
# 0.03820959171844407

# %% [markdown]
# 9. find all instances when 'Snow' was recorded

# %%
data['Precip Type'].value_counts()
# Out:
# Precip Type
# rain    85224
# snow    10712
# Name: count, dtype: int64

# %%
data[data['Precip Type'] == 'snow']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 1562   2006-12-13 02:00:00.000 +0100          Foggy        snow
# 1563   2006-12-13 03:00:00.000 +0100          Foggy        snow
# 1564   2006-12-13 04:00:00.000 +0100          Foggy        snow
# 1565   2006-12-13 05:00:00.000 +0100          Foggy        snow
# 1566   2006-12-13 06:00:00.000 +0100          Foggy        snow
# ...                              ...            ...         ...
# 93265  2016-03-28 05:00:00.000 +0200          Foggy        snow
# 93266  2016-03-28 06:00:00.000 +0200          Foggy        snow
# 93267  2016-03-28 07:00:00.000 +0200          Foggy        snow
# 93311  2016-03-03 03:00:00.000 +0100  Partly Cloudy        snow
# 93506  2016-03-09 06:00:00.000 +0100          Foggy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1562         -0.483333                 -4.150000      1.00            11.0929
# ...

# %% [markdown]
# 10. Find all instances where wind speed is above 10 and visibility is 25
#
# ---

# %%
data[(data['Wind Speed (km/h)'] > 10) & (data['Visibility (km)'] == 0.4830) ]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 1562   2006-12-13 02:00:00.000 +0100   Foggy        snow        -0.483333
# 1590   2006-12-14 06:00:00.000 +0100   Foggy        snow        -1.111111
# 2645   2006-02-26 05:00:00.000 +0100   Foggy        rain         1.066667
# 6987   2006-11-25 04:00:00.000 +0100   Foggy        rain         4.438889
# 19592  2008-12-31 08:00:00.000 +0100   Foggy        snow        -7.222222
# 28049  2009-12-19 17:00:00.000 +0100   Foggy        snow        -6.111111
# 28050  2009-12-19 18:00:00.000 +0100   Foggy        snow        -7.222222
# 29435  2009-01-18 11:00:00.000 +0100   Foggy        snow        -2.222222
# 33298  2009-11-24 11:00:00.000 +0100   Foggy        rain         6.111111
# 60077  2012-10-15 06:00:00.000 +0200   Foggy        rain        12.827778
# 64299  2013-01-10 03:00:00.000 +0100   Foggy        snow        -3.288889
# 82061  2015-01-02 08:00:00.000 +0100   Foggy        snow        -3.838889
# ...
